# %% [markdown]
# #monpremiercode

# %%
equipe = "Real Madrid"
type_sport = "football"
nombre_joueurs = 11
numero_joueur_5 = "Bellingham"

print("Nom de l'équipe :", equipe)
print("Nom du joueur portant le numéro 5 :", numero_joueur_5)
# Out:
# Nom de l'équipe : Real Madrid
# Nom du joueur portant le numéro 5 : Bellingham

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Gammoudi\Downloads\dataset.csv")

# %%
data.head(10)
# Out:
#    FacilityID                                   URL  \
# 0           1   https://toiletmap.gov.au/facility/1
# 1           2   https://toiletmap.gov.au/facility/2
# 2           3   https://toiletmap.gov.au/facility/3
# 3           4   https://toiletmap.gov.au/facility/4
# 4           5   https://toiletmap.gov.au/facility/5
# 5           6   https://toiletmap.gov.au/facility/6
# 6           7   https://toiletmap.gov.au/facility/7
# 7           9   https://toiletmap.gov.au/facility/9
# 8          15  https://toiletmap.gov.au/facility/15
# 9          16  https://toiletmap.gov.au/facility/16
#
#                           Name       FacilityType                    Address1  \
# 0          Sandy Beach Reserve    Park or reserve       Lost 15525, West Road
# 1                Point Reserve    Park or reserve         Lot 197, North Road
# 2         Success Hill Reserve    Park or reserve    Lot 2838, Seventh Avenue
# ...
